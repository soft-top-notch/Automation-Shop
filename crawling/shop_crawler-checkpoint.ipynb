# %%
import random
import csv
import logging

from shop_crawler import *
from selenium_helper import *
import common_actors

from contextlib import contextmanager

# %% [markdown]
# ### Prepare different urls to analyze

# %%
# All urls
all_urls = []
with open('../resources/pvio_vio_us_ca_uk_sample1.csv', 'r') as f:
    rows = csv.reader(f)
    for row in rows:
        url = row[0]
        if url:
            all_urls.append(url)

# Random sample urls
random.seed(1)
sample_urls = random.sample(all_urls, 100)

# Some good urls to analyze by hands
good_urls = [
    'curlebotanicals.com',
    'theglamourshop.com',
    'vape-fuel.com',
    'firstfitness.com',
    'sandlakedermatology.com',
    'getwaave.com',
    'dixieems.com',
    'jonessurgical.com',
    'srandd.com',
    'ambarygardens.com',
    'anabolicwarfare.com'
]

# %% [markdown]
# ### Mock user and payment information

# %%
user_info = UserInfo(
    first_name = 'John',
    last_name = 'Smith',
    country = 'United States',
    home = 34,
    street = 'Ocean drive',
    city = 'Miami',
    zip = '33125',
    state = 'FLorida',
    
    phone = '1231232',
    email = 'john@service.com'
)

billing_info = PaymentInfo(
    card_number = '1413232312312321',
    expire_date_year = 2020,
    expire_date_month = 12,
    card_name = 'Visa Card',
    card_type = 'Visa',
    cvc = '123'
)

# %%
selenium_path = '/usr/bin/chromedriver'

@contextmanager
def get_crawler(headless=True):
    global user_info, billing_info, selinium_path
    crawler = ShopCrawler(user_info, billing_info, selenium_path, headless=headless)
    common_actors.add_crawler_extensions(crawler)
    
    yield crawler

def get_driver(headless=True):
    global selenium_path   
    return create_chrome_driver(selenium_path, headless=headless)

# %% [markdown]
# ### Set up logging level

# %%
logger = logging.getLogger('shop_crawler')
logger.setLevel(logging.DEBUG)

handler = logging.StreamHandler()
formatter = logging.Formatter(
        '%(asctime)s %(name)-12s %(levelname)-8s %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# %% [markdown]
# ### Start crawling for every url

# %%
results = []
with get_crawler(headless=False) as crawler:
    for url in sample_urls:
        print('\n\n{}'.format(url))
        status = crawler.crawl(url, 30)
        print(status)
        results.append(status)
# Out:
# vaporworld.biz
# /home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 2018-07-15 03:48:34,491 shop_crawler INFO     processing state: new
# 2018-07-15 03:48:34,491 shop_crawler INFO     processing state: new
# 2018-07-15 03:48:34,498 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:48:34,498 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:48:34,626 shop_crawler INFO     new_state new, url http://vaporworld.biz/
# 2018-07-15 03:48:34,626 shop_crawler INFO     new_state new, url http://vaporworld.biz/
# 2018-07-15 03:48:34,632 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:48:34,632 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:49:05,126 shop_crawler INFO     new_state product_page, url https://www.vaporsupply.com/categories.php
# 2018-07-15 03:49:05,126 shop_crawler INFO     new_state product_page, url https://www.vaporsupply.com/categories.php
# 2018-07-15 03:49:05,179 shop_crawler INFO     found 6 frames
# 2018-07-15 03:49:05,179 shop_crawler INFO     found 6 frames
# 2018-07-15 03:49:05,184 shop_crawler INFO     processing state: product_page
# 2018-07-15 03:49:05,184 shop_crawler INFO     processing state: product_page
# 2018-07-15 03:49:05,189 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:49:05,189 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:49:54,103 shop_crawler DEBUG    clicking element: <a href="https://www.vaporsupply.com/cart.php?action=add&amp;product_id=1631" class="btn btn-alt btn-sm" title="Add To Cart">
#                 <span>Add To Cart</span>
#             </a>
# 2018-07-15 03:49:54,103 shop_crawler DEBUG    clicking element: <a href="https://www.vaporsupply.com/cart.php?action=add&amp;product_id=1631" class="btn btn-alt btn-sm" title="Add To Cart">
#                 <span>Add To Cart</span>
#             </a>
# 2018-07-15 03:50:03,382 shop_crawler DEBUG    result: True
# 2018-07-15 03:50:03,382 shop_crawler DEBUG    result: True
# 2018-07-15 03:50:03,403 shop_crawler INFO     new_state product_in_cart, url https://www.vaporsupply.com/cart.php?suggest=de3de505-95e5-43c0-b92e-6ed6ffcbfae6
# 2018-07-15 03:50:03,403 shop_crawler INFO     new_state product_in_cart, url https://www.vaporsupply.com/cart.php?suggest=de3de505-95e5-43c0-b92e-6ed6ffcbfae6
# 2018-07-15 03:50:03,466 shop_crawler INFO     found 6 frames
# 2018-07-15 03:50:03,466 shop_crawler INFO     found 6 frames
# 2018-07-15 03:50:03,474 shop_crawler INFO     processing state: product_in_cart
# 2018-07-15 03:50:03,474 shop_crawler INFO     processing state: product_in_cart
# 2018-07-15 03:50:03,476 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:50:03,476 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:50:44,482 shop_crawler DEBUG    clicking element: <a href="https://www.vaporsupply.com/checkout.php">
#                                 <span>Checkout</span>
#                             </a>
# 2018-07-15 03:50:44,482 shop_crawler DEBUG    clicking element: <a href="https://www.vaporsupply.com/checkout.php">
#                                 <span>Checkout</span>
#                             </a>
# 2018-07-15 03:50:51,265 shop_crawler DEBUG    result: True
# 2018-07-15 03:50:51,265 shop_crawler DEBUG    result: True
# 2018-07-15 03:51:01,570 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:01,570 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:01,609 shop_crawler INFO     found 6 frames
# 2018-07-15 03:51:01,609 shop_crawler INFO     found 6 frames
# 2018-07-15 03:51:01,702 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:01,702 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:01,811 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:01,811 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:01,819 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:01,819 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:01,911 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:01,911 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:01,976 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:01,976 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,052 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,052 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,055 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,055 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,177 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,177 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,346 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,346 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,415 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,415 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,418 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,418 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,471 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,471 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,503 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,503 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,588 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,588 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,592 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,592 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,662 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,662 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,695 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,695 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,775 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,775 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,778 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,778 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,837 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,837 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:02,873 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,873 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:02,958 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,958 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:51:02,961 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:02,961 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:51:03,021 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:03,021 shop_crawler DEBUG    Not found select options!
# 2018-07-15 03:51:03,062 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# 2018-07-15 03:51:03,062 shop_crawler INFO     new_state checkout_page, url https://www.vaporsupply.com/login.php
# Status: "Processing Finished at State" after processing url "vaporworld.biz"
#
#
# cvsciences.com
# /home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 2018-07-15 03:51:14,132 shop_crawler INFO     processing state: new
# 2018-07-15 03:51:14,132 shop_crawler INFO     processing state: new
# 2018-07-15 03:51:14,136 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:51:14,136 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:51:15,862 shop_crawler INFO     new_state new, url https://cvsciences.com/
# 2018-07-15 03:51:15,862 shop_crawler INFO     new_state new, url https://cvsciences.com/
# 2018-07-15 03:51:15,865 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:51:15,865 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:51:20,428 shop_crawler INFO     new_state new, url https://cvsciences.com/
# 2018-07-15 03:51:20,428 shop_crawler INFO     new_state new, url https://cvsciences.com/
# 2018-07-15 03:51:20,432 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 03:51:20,432 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 03:51:21,719 shop_crawler INFO     new_state new, url https://cvsciences.com/
# 2018-07-15 03:51:21,719 shop_crawler INFO     new_state new, url https://cvsciences.com/
# 2018-07-15 03:51:21,723 shop_crawler INFO     handler <common_actors.ToShopLink object at 0x7fddce0b2d68>
# 2018-07-15 03:51:21,723 shop_crawler INFO     handler <common_actors.ToShopLink object at 0x7fddce0b2d68>
# 2018-07-15 03:51:22,888 shop_crawler DEBUG    clicking element: <a href="https://cvsciences.com/consumer-products/">Consumer Products</a>
# 2018-07-15 03:51:22,888 shop_crawler DEBUG    clicking element: <a href="https://cvsciences.com/consumer-products/">Consumer Products</a>
# 2018-07-15 03:51:54,399 shop_crawler DEBUG    result: True
# 2018-07-15 03:51:54,399 shop_crawler DEBUG    result: True
# 2018-07-15 03:51:54,422 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# 2018-07-15 03:51:54,422 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# 2018-07-15 03:51:54,470 shop_crawler INFO     processing state: shop
# 2018-07-15 03:51:54,470 shop_crawler INFO     processing state: shop
# 2018-07-15 03:51:54,473 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:51:54,473 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:51:55,964 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# 2018-07-15 03:51:55,964 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# 2018-07-15 03:51:55,970 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:51:55,970 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:51:59,248 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# 2018-07-15 03:51:59,248 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# 2018-07-15 03:51:59,253 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 03:51:59,253 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 03:52:00,293 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# 2018-07-15 03:52:00,293 shop_crawler INFO     new_state shop, url https://cvsciences.com/consumer-products/
# Status: "Processing Finished at State" after processing url "cvsciences.com"
#
#
# walkinmycloset.com
# Status: "Not Available" after processing url "http://walkinmycloset.com"
#  Domain walkinmycloset.com for sale
#
#
# blackrosevapes.com
# Status: "Time Out" after processing url "http://blackrosevapes.com"
#
#
# fourriversbirdrescue.org
# Status: "Time Out" after processing url "http://fourriversbirdrescue.org"
#
#
# trelexa.org
# Status: "Time Out" after processing url "http://trelexa.org"
#
#
# webstersoccer.com
# 2018-07-15 03:55:14,885 shop_crawler INFO     processing state: new
# 2018-07-15 03:55:14,885 shop_crawler INFO     processing state: new
# 2018-07-15 03:55:14,895 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:55:14,895 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:55:22,798 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:22,798 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:22,862 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:22,862 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:24,758 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# 2018-07-15 03:55:24,758 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# 2018-07-15 03:55:24,762 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:55:24,762 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:55:28,516 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# 2018-07-15 03:55:28,516 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# 2018-07-15 03:55:28,518 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 03:55:28,518 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 03:55:34,459 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
# 2018-07-15 03:55:34,459 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:34,485 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:34,485 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:36,579 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# 2018-07-15 03:55:36,579 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# 2018-07-15 03:55:36,590 shop_crawler INFO     handler <common_actors.ToShopLink object at 0x7fddce0b2d68>
# 2018-07-15 03:55:36,590 shop_crawler INFO     handler <common_actors.ToShopLink object at 0x7fddce0b2d68>
# 2018-07-15 03:55:41,963 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:41,963 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:41,993 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
# 2018-07-15 03:55:41,993 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:55:43,263 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# 2018-07-15 03:55:43,263 shop_crawler INFO     new_state new, url http://www.lakefrontsc.com/
# Status: "Processing Finished at State" after processing url "webstersoccer.com"
#
#
# tampahumidor.com
# /home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 2018-07-15 03:56:03,401 shop_crawler INFO     processing state: new
# 2018-07-15 03:56:03,401 shop_crawler INFO     processing state: new
# 2018-07-15 03:56:03,431 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:56:03,431 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:56:08,778 shop_crawler INFO     new_state new, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/
# 2018-07-15 03:56:08,778 shop_crawler INFO     new_state new, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/
# 2018-07-15 03:56:08,784 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:56:08,784 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:56:16,144 shop_crawler INFO     new_state product_page, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/cigars/la-mission-du-latelier.php
# 2018-07-15 03:56:16,144 shop_crawler INFO     new_state product_page, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/cigars/la-mission-du-latelier.php
# 2018-07-15 03:56:16,195 shop_crawler INFO     processing state: product_page
# 2018-07-15 03:56:16,195 shop_crawler INFO     processing state: product_page
# 2018-07-15 03:56:16,197 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:56:16,197 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:56:21,656 shop_crawler INFO     new_state product_page, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/cigars/la-mission-du-latelier.php
# 2018-07-15 03:56:21,656 shop_crawler INFO     new_state product_page, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/cigars/la-mission-du-latelier.php
# 2018-07-15 03:56:21,663 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:56:21,663 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:56:26,350 shop_crawler INFO     new_state product_page, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/cigars/la-mission-du-latelier.php
# 2018-07-15 03:56:26,350 shop_crawler INFO     new_state product_page, url https://www.seriouscigars.com/info/Tampa-Humidor?utm_source=tampahumidor/cigars/la-mission-du-latelier.php
# Status: "Processing Finished at State" after processing url "tampahumidor.com"
#
#
# gotbloody.com
# Status: "Time Out" after processing url "http://gotbloody.com"
#
#
# personalcarenow.com
# 2018-07-15 03:57:31,399 shop_crawler INFO     processing state: new
# 2018-07-15 03:57:31,399 shop_crawler INFO     processing state: new
# 2018-07-15 03:57:31,402 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:57:31,402 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:57:34,053 shop_crawler INFO     new_state new, url http://personalcarenow.com/
# 2018-07-15 03:57:34,053 shop_crawler INFO     new_state new, url http://personalcarenow.com/
# 2018-07-15 03:57:34,062 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:57:34,062 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 03:57:39,732 shop_crawler INFO     new_state product_page, url http://www.personalcarenow.com/index.php?main_page=product_info&cPath=27&products_id=128&zenid=2a7157c1342238c5113114e4a46a3bab
# 2018-07-15 03:57:39,732 shop_crawler INFO     new_state product_page, url http://www.personalcarenow.com/index.php?main_page=product_info&cPath=27&products_id=128&zenid=2a7157c1342238c5113114e4a46a3bab
# 2018-07-15 03:57:39,769 shop_crawler INFO     processing state: product_page
# 2018-07-15 03:57:39,769 shop_crawler INFO     processing state: product_page
# 2018-07-15 03:57:39,773 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:57:39,773 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:57:42,030 shop_crawler DEBUG    clicking element: <input class="cssButton button_in_cart" onmouseover="this.className='cssButtonHover button_in_cart button_in_cartHover'" onmouseout="this.className='cssButton button_in_cart'" type="submit" value="Add to Cart">
# 2018-07-15 03:57:42,030 shop_crawler DEBUG    clicking element: <input class="cssButton button_in_cart" onmouseover="this.className='cssButtonHover button_in_cart button_in_cartHover'" onmouseout="this.className='cssButton button_in_cart'" type="submit" value="Add to Cart">
# 2018-07-15 03:57:44,150 shop_crawler DEBUG    result: True
# 2018-07-15 03:57:44,150 shop_crawler DEBUG    result: True
# 2018-07-15 03:57:44,169 shop_crawler INFO     new_state product_in_cart, url http://www.personalcarenow.com/index.php?main_page=shopping_cart
# 2018-07-15 03:57:44,169 shop_crawler INFO     new_state product_in_cart, url http://www.personalcarenow.com/index.php?main_page=shopping_cart
# 2018-07-15 03:57:44,205 shop_crawler INFO     processing state: product_in_cart
# 2018-07-15 03:57:44,205 shop_crawler INFO     processing state: product_in_cart
# 2018-07-15 03:57:44,207 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:57:44,207 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:57:46,478 shop_crawler DEBUG    clicking element: <a href="https://www.personalcarenow.com/index.php?main_page=checkout_shipping"><span class="cssButton button_checkout" onmouseover="this.className='cssButtonHover button_checkout button_checkoutHover'" onmouseout="this.className='cssButton button_checkout'">&nbsp;Checkout&nbsp;</span></a>
# 2018-07-15 03:57:46,478 shop_crawler DEBUG    clicking element: <a href="https://www.personalcarenow.com/index.php?main_page=checkout_shipping"><span class="cssButton button_checkout" onmouseover="this.className='cssButtonHover button_checkout button_checkoutHover'" onmouseout="this.className='cssButton button_checkout'">&nbsp;Checkout&nbsp;</span></a>
# 2018-07-15 03:57:50,167 shop_crawler DEBUG    result: True
# 2018-07-15 03:57:50,167 shop_crawler DEBUG    result: True
# 2018-07-15 03:58:00,335 shop_crawler INFO     new_state checkout_page, url https://www.personalcarenow.com/index.php?main_page=login
# 2018-07-15 03:58:00,335 shop_crawler INFO     new_state checkout_page, url https://www.personalcarenow.com/index.php?main_page=login
# 2018-07-15 03:58:00,817 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:58:00,817 shop_crawler INFO     processing state: checkout_page
# Status: "Processing Finished at State" after processing url "personalcarenow.com"
#
#
# ladyfatemahtrust.org
# Status: "Not Available" after processing url "http://ladyfatemahtrust.org"
#
#
# the420line.com
# 2018-07-15 03:58:27,719 shop_crawler INFO     processing state: new
# 2018-07-15 03:58:27,719 shop_crawler INFO     processing state: new
# 2018-07-15 03:58:27,722 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:58:27,722 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 03:58:31,947 shop_crawler DEBUG    clicking element: <a href="/?add-to-cart=272" data-quantity="1" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="272" data-product_sku="LBV420SC-1" aria-label="Add “The &quot;420&quot; Line - Shop Startup Kit” to your cart" rel="nofollow">Add to cart</a>
# 2018-07-15 03:58:31,947 shop_crawler DEBUG    clicking element: <a href="/?add-to-cart=272" data-quantity="1" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="272" data-product_sku="LBV420SC-1" aria-label="Add “The &quot;420&quot; Line - Shop Startup Kit” to your cart" rel="nofollow">Add to cart</a>
# 2018-07-15 03:58:33,711 shop_crawler DEBUG    result: True
# 2018-07-15 03:58:33,711 shop_crawler DEBUG    result: True
# 2018-07-15 03:58:33,723 shop_crawler INFO     new_state product_in_cart, url http://the420line.com/?add-to-cart=272
# 2018-07-15 03:58:33,723 shop_crawler INFO     new_state product_in_cart, url http://the420line.com/?add-to-cart=272
# 2018-07-15 03:58:33,762 shop_crawler INFO     processing state: product_in_cart
# 2018-07-15 03:58:33,762 shop_crawler INFO     processing state: product_in_cart
# 2018-07-15 03:58:33,765 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:58:33,765 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:58:37,906 shop_crawler INFO     new_state product_in_cart, url http://the420line.com/?add-to-cart=272
# 2018-07-15 03:58:37,906 shop_crawler INFO     new_state product_in_cart, url http://the420line.com/?add-to-cart=272
# 2018-07-15 03:58:37,911 shop_crawler INFO     handler <common_actors.ToCartLink object at 0x7fddce0b2dd8>
# 2018-07-15 03:58:37,911 shop_crawler INFO     handler <common_actors.ToCartLink object at 0x7fddce0b2dd8>
# 2018-07-15 03:58:41,801 shop_crawler DEBUG    clicking element: <a href="https://the420line.com/cart/">Cart<span class="colorbar"></span></a>
# 2018-07-15 03:58:41,801 shop_crawler DEBUG    clicking element: <a href="https://the420line.com/cart/">Cart<span class="colorbar"></span></a>
# 2018-07-15 03:58:48,026 shop_crawler DEBUG    result: True
# 2018-07-15 03:58:48,026 shop_crawler DEBUG    result: True
# 2018-07-15 03:59:18,142 shop_crawler INFO     new_state cart_page, url https://the420line.com/cart/
# 2018-07-15 03:59:18,142 shop_crawler INFO     new_state cart_page, url https://the420line.com/cart/
# 2018-07-15 03:59:18,181 shop_crawler INFO     processing state: cart_page
# 2018-07-15 03:59:18,181 shop_crawler INFO     processing state: cart_page
# 2018-07-15 03:59:18,192 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:59:18,192 shop_crawler INFO     handler <common_actors.ToCheckout object at 0x7fddce0b2da0>
# 2018-07-15 03:59:22,201 shop_crawler DEBUG    clicking element: <a href="https://the420line.com/cart/checkout/" class="checkout-button button alt wc-forward">
# 	Proceed to checkout</a>
# 2018-07-15 03:59:22,201 shop_crawler DEBUG    clicking element: <a href="https://the420line.com/cart/checkout/" class="checkout-button button alt wc-forward">
# 	Proceed to checkout</a>
# 2018-07-15 03:59:25,106 shop_crawler DEBUG    result: True
# 2018-07-15 03:59:25,106 shop_crawler DEBUG    result: True
# 2018-07-15 03:59:35,236 shop_crawler INFO     new_state checkout_page, url https://the420line.com/cart/checkout/
# 2018-07-15 03:59:35,236 shop_crawler INFO     new_state checkout_page, url https://the420line.com/cart/checkout/
# 2018-07-15 03:59:35,340 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:59:35,340 shop_crawler INFO     processing state: checkout_page
# 2018-07-15 03:59:35,348 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:59:35,348 shop_crawler INFO     handler <common_actors.PaymentFields object at 0x7fddce0b2e10>
# 2018-07-15 03:59:44,354 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:59:44,354 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 320, in execute
#     self.error_handler.check_response(response)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.15.0-24-generic x86_64)
#
#
# 2018-07-15 03:59:47,013 shop_crawler DEBUG    Exception during checking element Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 29, in can_click
#     return element.is_enabled() and element.is_displayed()
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 159, in is_enabled
#     return self._execute(Command.IS_ELEMENT_ENABLED)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
# ...
# 2018-07-15 04:01:08,058 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:08,058 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:08,066 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 04:01:08,066 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 04:01:11,878 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:11,878 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:11,884 shop_crawler INFO     handler <common_actors.ToShopLink object at 0x7fddce0b2d68>
# 2018-07-15 04:01:11,884 shop_crawler INFO     handler <common_actors.ToShopLink object at 0x7fddce0b2d68>
# 2018-07-15 04:01:14,851 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:14,851 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:14,957 shop_crawler INFO     processing state: new
# 2018-07-15 04:01:14,957 shop_crawler INFO     processing state: new
# 2018-07-15 04:01:14,964 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 04:01:14,964 shop_crawler INFO     handler <common_actors.AddToCart object at 0x7fddce0b2cc0>
# 2018-07-15 04:01:15,125 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:15,125 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:15,129 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 04:01:15,129 shop_crawler INFO     handler <common_actors.GoogleForProductPage object at 0x7fddce0b2cf8>
# 2018-07-15 04:01:18,514 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:18,514 shop_crawler INFO     new_state new, url https://www.medial.com/
# 2018-07-15 04:01:18,518 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 04:01:18,518 shop_crawler INFO     handler <common_actors.ToProductPageLink object at 0x7fddce0b2d30>
# 2018-07-15 04:01:20,718 shop_crawler ERROR    Unexpected exception during processing http://streaming.co.uk
# Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 306, in crawl
#     new_state = self.process_state(driver, state, context)
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 262, in process_state
#     new_state = handler.act(driver, state, context)
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 181, in act
#     step = self.process_page(driver, state, context)
#   File "/home/jack/working_directory/David/trace_automation/crawling/common_actors.py", line 144, in process_page
#     links = self.find_to_product_links(driver)
#   File "/home/jack/working_directory/David/trace_automation/crawling/common_actors.py", line 141, in find_to_product_links
#     return find_links(driver, ['/product', '/commodity', '/drug'], by_path=True)
#   File "/home/jack/working_directory/David/trace_automation/crawling/common_actors.py", line 63, in find_links
#     href = link.get_attribute("href")
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 143, in get_attribute
#     resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 318, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 472, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 496, in _request
#     resp = self._conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/lib/python3.5/socket.py", line 575, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 308, in crawl
#     break
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 21, in __exit__
#     url = self.driver.current_url
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 668, in current_url
#     return self.execute(Command.GET_CURRENT_URL)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 318, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 472, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 495, in _request
#     self._conn.request(method, parsed_url.path, body, headers)
#   File "/usr/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/usr/lib/python3.5/http/client.py", line 1141, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/usr/lib/python3.5/http/client.py", line 974, in putrequest
#     raise CannotSendRequest(self.__state)
# http.client.CannotSendRequest: Request-sent
# 2018-07-15 04:01:20,718 shop_crawler ERROR    Unexpected exception during processing http://streaming.co.uk
# Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 306, in crawl
#     new_state = self.process_state(driver, state, context)
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 262, in process_state
#     new_state = handler.act(driver, state, context)
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 181, in act
#     step = self.process_page(driver, state, context)
#   File "/home/jack/working_directory/David/trace_automation/crawling/common_actors.py", line 144, in process_page
#     links = self.find_to_product_links(driver)
#   File "/home/jack/working_directory/David/trace_automation/crawling/common_actors.py", line 141, in find_to_product_links
#     return find_links(driver, ['/product', '/commodity', '/drug'], by_path=True)
#   File "/home/jack/working_directory/David/trace_automation/crawling/common_actors.py", line 63, in find_links
#     href = link.get_attribute("href")
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 143, in get_attribute
#     resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py", line 628, in _execute
#     return self._parent.execute(command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 318, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 472, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 496, in _request
#     resp = self._conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/lib/python3.5/socket.py", line 575, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jack/working_directory/David/trace_automation/crawling/shop_crawler.py", line 308, in crawl
#     break
#   File "/home/jack/working_directory/David/trace_automation/crawling/selenium_helper.py", line 21, in __exit__
#     url = self.driver.current_url
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 668, in current_url
#     return self.execute(Command.GET_CURRENT_URL)['value']
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py", line 318, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 472, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/jack/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py", line 495, in _request
#     self._conn.request(method, parsed_url.path, body, headers)
#   File "/usr/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/usr/lib/python3.5/http/client.py", line 1141, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/usr/lib/python3.5/http/client.py", line 974, in putrequest
#     raise CannotSendRequest(self.__state)
# http.client.CannotSendRequest: Request-sent
# Status: "Processing Finished at State" after processing url "streaming.co.uk"
#
#
# parkermotherandchild.org
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-13-89b3dfe29f6a> in <module>()
#       3     for url in sample_urls:
#       4         print('\n\n{}'.format(url))
# ----> 5         status = crawler.crawl(url, 30)
#       6         print(status)
#       7         results.append(status)
#
# ~/working_directory/David/trace_automation/crawling/shop_crawler.py in crawl(self, domain, wait_response_seconds)
#     279         context = StepContext(domain, self._user_info, self._payment_info)
#     280
# --> 281         driver = self.get_driver()
#     282         state = States.new
#     283
#
# ~/working_directory/David/trace_automation/crawling/shop_crawler.py in get_driver(self, timeout)
#     236     def get_driver(self, timeout=60):
#     237         if self._driver:
# --> 238             num_of_tabs = count_tabs(self._driver)
#     239             for x in range(1, num_of_tabs):
#     240                 close_tab(self._driver)
#
# ~/working_directory/David/trace_automation/crawling/selenium_helper.py in count_tabs(driver)
#      45
#      46 def count_tabs(driver):
# ---> 47     return len(driver.window_handles)
#      48
#      49
#
# ~/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in window_handles(self)
#     723             return self.execute(Command.W3C_GET_WINDOW_HANDLES)['value']
#     724         else:
# --> 725             return self.execute(Command.GET_WINDOW_HANDLES)['value']
#     726
#     727     def maximize_window(self):
#
# ~/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     316
#     317         params = self._wrap_value(params)
# --> 318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
#     320             self.error_handler.check_response(response)
#
# ~/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     470         data = utils.dump_json(params)
#     471         url = '%s%s' % (self._url, path)
# --> 472         return self._request(command_info[0], url, body=data)
#     473
#     474     def _request(self, method, url, body=None):
#
# ~/working_directory/David/trace_automation/venv/lib/python3.5/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     493                 body = None
#     494             try:
# --> 495                 self._conn.request(method, parsed_url.path, body, headers)
#     496                 resp = self._conn.getresponse()
#     497             except (httplib.HTTPException, socket.error):
#
# /usr/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1104     def request(self, method, url, body=None, headers={}):
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#    1108     def _set_content_length(self, body, method):
#
# /usr/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1149             # default charset of iso-8859-1.
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#    1153     def getresponse(self):
#
# /usr/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1100         else:
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#    1104     def request(self, method, url, body=None, headers={}):
#
# /usr/lib/python3.5/http/client.py in _send_output(self, message_body)
#     932         del self._buffer[:]
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#     936             self.send(message_body)
#
# /usr/lib/python3.5/http/client.py in send(self, data)
#     875         if self.sock is None:
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#     879                 raise NotConnected()
#
# /usr/lib/python3.5/http/client.py in connect(self)
#     847         """Connect to the host and port specified in __init__."""
#     848         self.sock = self._create_connection(
# --> 849             (self.host,self.port), self.timeout, self.source_address)
#     850         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     851
#
# /usr/lib/python3.5/socket.py in create_connection(address, timeout, source_address)
#     709
#     710     if err is not None:
# --> 711         raise err
#     712     else:
#     713         raise error("getaddrinfo returns an empty list")
#
# /usr/lib/python3.5/socket.py in create_connection(address, timeout, source_address)
#     700             if source_address:
#     701                 sock.bind(source_address)
# --> 702             sock.connect(sa)
#     703             return sock
#     704
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %%
states = {}
for status in results:
    if isinstance(status, ProcessingStatus):
        states[status.state] = states.get(status.state, 0) + 1
        
print(states)

# %% [markdown]
# ### Test Empty cart processing

# %%
# Make it True if you want to test empty cart detection
test_empty_cart = False

checkout_pages = [
    'http://vape-fuel.com/checkout/cart/',
    'https://store-bb7f1.mybigcommerce.com/cart.php',
    'https://www.firstfitness.com/index.php?pg=signup',
    'https://store.sandlakedermatology.com/checkout/cart/',
    'https://www.dixieems.com/cart.asp',
    'http://www.jonessurgical.com/quick-order'    
]

if test_empty_cart:
    driver = get_driver()
    
    for url in checkout_pages:
        driver.get(url)
        time.sleep(30)
        
        is_empty_cart = common_actors.is_empty_cart(driver)
        print('url: {}, is empty cart: {}'.format(url, is_empty_cart))
        assert is_empty_cart

    driver.quit()

# %%
test_broken_sites = False

not_available = [
    'juicyliquid.com',
    'gotbloody.com',
    'trelexa.org'
]

error = [
    'tampahumidor.com',
    'seriouscigars.com'    
]

timeout = [
    'moneynetint.com'
]

domains_for_sale = [
    'walkinmycloset.com'
]
        

if test_broken_sites:
    with get_crawler() as crawler:
        for url in domains_for_sale:
            print(url)
            status = crawler.crawl(url)
            assert isinstance(status, NotAvailable), '{} must be not available'.format(url)
        
        for url in timeout:
            print(url)
            status = crawler.crawl(url)
            assert isinstance(status, Timeout) or isinstance(status, NotAvailable), \
                '{} must be not timed out'.format(url)

        for url in not_available:
            print(url)
            status = crawler.crawl(url)
            assert isinstance(status, NotAvailable), '{} must be not available'.format(url)

        for url in error:
            print(url)
            status = crawler.crawl(url)
            assert isinstance(status, RequestError), '{} must produce an error'.format(url)
